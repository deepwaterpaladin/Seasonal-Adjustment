# %%
from bond_yield import *

test = ThirtyYear()
test.plot()

# %%
from bond_yield import *

test = TenYear()
test.plot()

# %%
from bond_yield import *

test = SevenYear()
test.plot()

# %%
from bond_yield import *

test = FiveYear()
test.plot()

# %%
from bond_yield import *

all_test = Bond()
all_test.plot_all_one_week()
